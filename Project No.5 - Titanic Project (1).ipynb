# %% [raw]
# Data description - The Titanic Problem is based on the sinking of the ‘Unsinkable’ ship Titanic in early 1912. It gives you information about multiple people like their ages, sexes, sibling counts, embarkment points, and whether or not they survived the disaster. Based on these features, you have to predict if an arbitrary passenger on Titanic would survive the sinking or not.

# %%
# Importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# Step 1. Data Selection

# %%
# loading Dataset

df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.head() #showing first five rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()  # showing last five rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape   #shape of dataset
# Out:
# (891, 12)

# %% [raw]
# There are totl 891 rows and 12 columns in dataset

# %%
pd.set_option('display.max_rows',None)

# %% [raw]
# pd.set_option('display.max_rows',None) - main purpose of using this is it will display all rows (if more than 10 rows) instead of first 5 and last 5.

# %%
df.info() # Information about dataset like null values,data type etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [raw]
# There are null values present in Age (177), Cabin(687) and Embarked(2).

# %%
df.dtypes  #data type
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [raw]
# PassengerId,Survived,Pclass,Sibsp and Parch has intger datset; Name,Sex,Ticket, Cabin and Embarked has Object dataset and Age and Fare has float dataset.

# %% [raw]
# Step No 2. Data Description

# %%
df.describe()  #statistical summary
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [raw]
# In above dataset there are total 891 counts across every columns except Age. There are NANs in age column. Describe method helps to understand about data set. It shows attributes like mean,max,min,std deviation, 25%,50%,75%.

# %% [raw]
# By comparing mean and 50% value attributes, there is big difference between Survived, Pclass, Age, Sibsp, Parch and Fare. So there are outliers present in it.

# %%
# Let's visualized above dataset.

plt.figure(figsize=(20,15))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Vaiables summary")
plt.show()

# %% [raw]
# It helps to visualized dataset better.It visualzed all variables except count of variable.

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].value_counts().idxmax) #filling nans present in dataset.

# %%
df=df.drop(columns=['Cabin']) # Dropping Cabin column

# %%
df['Age']=df['Age'].fillna(df['Age'].mean)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [raw]
# There are no null values in dataset now.

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [raw]
# 0 represent not survived (549) and 1 represent survived(342).

# %%
data = df['Survived'].value_counts()

# %%
#Let's visulaized target parameter.

plt.figure(figsize=(15,10))
sns.barplot(data.index,data.values,alpha=0.6)
plt.xlabel("Parameters",fontsize=14)
plt.ylabel("count",fontsize=14)
plt.title("Non-Survival Vs Survival ")
plt.show()
# Out:
# C:\Users\Rajat Jibhkate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# Bar Plot helps to visualized all parameters better. Above graphs showing Survival parameter (X-Axis) and there number of data points count (Y-Axis).

# %% [raw]
# Now visualized every parameter (features) with Survival (Label) parameter with help of plots.

# %%
sns.barplot(x='Pclass',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %% [raw]
# Above graphs helps to understand relation between Pclass and Survived.

# %%
plt.figure(figsize=(60,20))
sns.barplot(x='Age',y='Survived',data=df)
plt.show()

# %% [raw]
# Above graphs helps to understand relation between Age and Survived.

# %%
sns.barplot(x='SibSp',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Survived'>

# %% [raw]
# Above graphs helps to understand relation between Sibsp and Survived.

# %%
sns.barplot(x='Parch',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Survived'>

# %% [raw]
# Above graphs helps to understand relation between Parch and Survived.

# %%
plt.figure(figsize=(90,30))
sns.barplot(x='Fare',y='Survived',data=df)
plt.show()

# %%
Above graphs helps to understand relation between Fare and Survived.

# %%
sns.barplot(x='Embarked',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Survived'>

# %% [raw]
# Above graphs helps to understand relation between Embarked and Survived.

# %%
sns.barplot(x='Sex',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %% [raw]
# Above graphs helps to understand relation between Sex and Survived.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                           Allen, Mr. William Henry    male  35      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.shape
# Out:
# (891, 11)

# %%
df=df.drop(columns=['Name','Ticket'])  # Dropping Column.

# %%
df=df.drop(columns=['PassengerId'])  # Dropping Column.

# %%
df.head()
# Out:
#    Survived  Pclass  Sex Age  SibSp  Parch     Fare Embarked
# 0         0       2    1  22      1      0   7.2500        S
# 1         1       0    0  38      1      0  71.2833        C
# 2         1       2    0  26      0      0   7.9250        S
# 3         1       0    0  35      1      0  53.1000        S
# 4         0       2    1  35      0      0   8.0500        S

# %%
ports ={"S":0, "C":1,"Q":2}
data=[df]

for dataset in data:
    dataset["Embarked"]=dataset["Embarked"].map(ports)   #coverting Embarked into numeric value.

# %%
df.head()
# Out:
#    Survived  Pclass  Sex Age  SibSp  Parch     Fare  Embarked
# 0         0       2    1  22      1      0   7.2500       0.0
# 1         1       0    0  38      1      0  71.2833       1.0
# 2         1       2    0  26      0      0   7.9250       0.0
# 3         1       0    0  35      1      0  53.1000       0.0
# 4         0       2    1  35      0      0   8.0500       0.0

# %% [raw]
# Step 3. Data tranformation and derivation of new attributes.

# %%
corr_mat = df.corr() # Checking for correlation

# %%
corr_mat
# Out:
#           Survived    Pclass       Sex     SibSp     Parch      Fare  Embarked
# Survived  1.000000 -0.338481 -0.543351 -0.035322  0.081629  0.257307  0.108669
# Pclass   -0.338481  1.000000  0.131900  0.083081  0.018443 -0.549500  0.043835
# Sex      -0.543351  0.131900  1.000000 -0.114631 -0.245489 -0.182333 -0.118593
# SibSp    -0.035322  0.083081 -0.114631  1.000000  0.414838  0.159651 -0.060606
# Parch     0.081629  0.018443 -0.245489  0.414838  1.000000  0.216225 -0.079320
# Fare      0.257307 -0.549500 -0.182333  0.159651  0.216225  1.000000  0.063462
# Embarked  0.108669  0.043835 -0.118593 -0.060606 -0.079320  0.063462  1.000000

# %%
# visulization of correlated values.

plt.figure(figsize=(25,20))
sns.heatmap(corr_mat,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [raw]
# All columns of database are not positively correlated.
# PassengerId has 1.3%, Survived has 26%, Pclass has -55%, Sibsp has 16%, Parch has 22%, Fare has 100%.
# Max Correlation: Fare
# Min Correlation: Survived

# %% [raw]
# Step 4. Data standarization and normalization

# %%
df.skew() #to check skewness
# Out:
# Survived    0.478523
# Pclass     -0.630548
# Sex        -0.618921
# SibSp       3.695352
# Parch       2.749117
# Fare        4.787317
# Embarked    1.539926
# dtype: float64

# %% [raw]
# Normalized data range has skewnees ranges between +0.5 to -0.5.
# column has skewness - Pclass, Sibsp, Parch, Fare,Embarked.
# Column does not have skewness - Survived
#
# Let's visualized skewness with help of displot

# %%
sns.distplot(df['Pclass'])
# Out:
# C:\Users\Rajat Jibhkate\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Pclass', ylabel='Density'>

# %%
sns.distplot(df['Survived'])
# Out:
# C:\Users\Rajat Jibhkate\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Survived', ylabel='Density'>

# %%
sns.distplot(df['SibSp'])
# Out:
# C:\Users\Rajat Jibhkate\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SibSp', ylabel='Density'>

# %%
sns.distplot(df['Parch'])
# Out:
# C:\Users\Rajat Jibhkate\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Parch', ylabel='Density'>

# %%
sns.distplot(df['Fare'])
# Out:
# C:\Users\Rajat Jibhkate\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
sns.distplot(df['Embarked'])
# Out:
# C:\Users\Rajat Jibhkate\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Embarked', ylabel='Density'>

# %% [raw]
# Removing skewness from dataset with help of zscore.

# %%
from scipy.stats import zscore  #Importing requried library.

# %%
z = np.abs(zscore(df))
z.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-0fa278a5c9f0> in <module>
# ----> 1 z = np.abs(zscore(df))
#       2 z.shape
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in zscore(a, axis, ddof, nan_policy)
#    2495         sstd = np.nanstd(a=a, axis=axis, ddof=ddof, keepdims=True)
#    2496     else:
# -> 2497         mns = a.mean(axis=axis, keepdims=True)
#    2498         sstd = a.std(axis=axis, ddof=ddof, keepdims=True)
#    2499
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     158             is_float16_result = True
#     159
# --> 160     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     161     if isinstance(ret, mu.ndarray):
#     162         ret = um.true_divide(
#
# TypeError: unsupported operand type(s) for +: 'float' and 'method'

# %% [raw]
# Step 5. Creation of train and test data sets using optimum parameters

# %%
Y = df['Survived']
X = df.drop(columns=['Survived']) # Dividing dataset into X and Y.

# %%
X.head() #All columns without Survived column
# Out:
#    Pclass  Sex Age  SibSp  Parch     Fare  Embarked
# 0       2    1  22      1      0   7.2500       0.0
# 1       0    0  38      1      0  71.2833       1.0
# 2       2    0  26      0      0   7.9250       0.0
# 3       0    0  35      1      0  53.1000       0.0
# 4       2    1  35      0      0   8.0500       0.0

# %%
Y.head() #Only Survived column
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
# Data Scaling
#StandardScaler = (X-mean)/std

from sklearn.preprocessing import StandardScaler # Importing requried library

scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)
x_scaled
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-976d41e2d149> in <module>
#       5
#       6 scaler = StandardScaler()
# ----> 7 x_scaled = scaler.fit_transform(X)
#       8 x_scaled
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
#     669     def partial_fit(self, X, y=None):
#
# ...

# %%
# Split data into train and test. Model will be built on training data and tested on test data.

from sklearn.model_selection import train_test_split  #Importing requied library

x_train,x_test,y_train,y_test = train_test_split(x_scaled,Y,test_size=0.25,random_state=340)
y_train

# %% [raw]
# Step 6. Model training using ML algorithm

# %% [raw]
# Logistic Regression

# %%
# Model instatiating and training

from sklearn.linear_model import LogisticRegression #Importing required lib.
from sklearn.metrics import classification_report

LR = LogisticRegression()
LR.fit(x_train,y_train)
predlr = LR.predict(x_test)

print(accuracy_score(y_test,predlr))

print(confusion_matrix(y_test,predlr))

print(classification_report(y_test,predlr))

# %% [raw]
# KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier   #Importing requried lib.
KNN = KNeighborsClassifier()
KNN.fit(x_train,y_train)
predknn = KNN.predict(x_test)

print(accuracy_score(y_test,predknn))

print(confusion_matrix(y_test,predknn))

print(classification_report(y_test,predknn))

# %% [raw]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier     # Importing required lib
RAN = RandomForestClassifier()
RAN.fit(x_train,y_train)
predran = RAN.predict(x_test)

print(accuracy_score(y_test,predran))

print(confusion_matrix(y_test,predran))

print(classification_report(y_test,predran))

# %%
Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier    #Importing requried lib.
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt = dt.predict(x_test)

print(accuracy_score(y_test,preddt))

print(confusion_matrix(y_test,preddt))

print(classification_report(y_test,preddt))

# %%
from sklearn.model_selection import cross_val_score  #Importing requried lob.

# %%
scr = cross_val_score(LR,X,Y,cv=3)
print('Cross validation score for Logistic Regression :',scr.mean())

# %%
scr = cross_val_score(dt,X,Y,cv=3)
print('Cross validation score for Decision Tree Classifer:',scr.mean())

# %%
scr = cross_val_score(KNN,X,Y,cv=3)
print('Cross validation score for KNN :',scr.mean())

# %%
scr = cross_val_score(RAN,X,Y,cv=3)
print('Cross validation score for Random Forest Classifer :',scr.mean())

# %% [raw]
# Step No 7. Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV    #Importing requried lib.

# %%
#RandomForestClassifier

parameters = {'n_estimators':[200,700],
             'max_features':['auto','sqrt','log2'],
             'max_depth':[4,5,6,7,8],
             'criterion':['gini','entropy']}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameters,cv=3)

# %%
GCV.fit(x_train,y_train)

# %%
GCV.best_params_     #printing the best parameter found by GridSearchCV

# %%
mod = RandomForestClassifier(criterion='entropy',max_features='log2',max_depth=6, n_estimators=200)

mod.fit(x_train,y_train)
pred = mod.predict(x_test)
print(accuracy_score(y_test,pred)*100)

# %% [raw]
# Step No. 8 Saving Model

# %%
import joblib  #importing requried lib.
joblib.dump(mod."Titanic.pkl")
